# %% [markdown]
# <a href="https://colab.research.google.com/github/lilipant10/Learning-Pandas/blob/main/Creating_bar_charts_with_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_avg_data.csv")
df
# Out:
#        store_loc  num_emp  avg_emp_tenure_in_years  avg_emp_rating  \
# 0        Atlanta       17                        1               3
# 1         Austin       12                        6               4
# 2        Chicago       22                        3               3
# 3         Denver       21                        5               4
# 4        Detroit       10                        1               2
# 5          Miami       30                        2               3
# 6       Portland       13                        4               4
# 7  San Francisco       20                        1               1
# 8        Seattle       25                       10               5
#
#   emp_break_room
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# 5             No
# 6            Yes
# 7             No
# 8            Yes

# %%
sns.barplot(x='avg_emp_rating',y='avg_emp_tenure_in_years',data=df)
plt.show()

# %%
sns.barplot(x='avg_emp_rating',y='avg_emp_tenure_in_years',data=df,hue='emp_break_room')
plt.show()

# %%
sns.set_theme(style='darkgrid', palette='dark')
sns.barplot(x='avg_emp_rating',y='avg_emp_tenure_in_years',data=df,hue='emp_break_room')
plt.show()
