# %% [markdown]
# <a href="https://colab.research.google.com/github/lilipant10/Learning-Pandas/blob/main/Extracting_data_by_index_number_and_custom_label_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/loss_prevention_data.csv')
df
# Out:
#             item      item_dept  item_cost  num_thefts   date
# 0     cell phone    electronics     399.99           6  1-Jun
# 1          razor  personal care       4.92           2  1-Jun
# 2     cell phone    electronics     399.99           4  2-Jun
# 3  phone charger    electronics       6.99           1  2-Jun
# 4      sunscreen  personal care       7.98           1  3-Jun
# 5     cell phone    electronics     399.99           8  4-Jun

# %%
df.iloc[5]
# Out:
# item           cell phone
# item_dept     electronics
# item_cost          399.99
# num_thefts              8
# date                4-Jun
# Name: 5, dtype: object

# %%
df.iloc[[5]]
# Out:
#          item    item_dept  item_cost  num_thefts   date
# 5  cell phone  electronics     399.99           8  4-Jun

# %%
df.iloc[[0,1,5]]
# Out:
#          item      item_dept  item_cost  num_thefts   date
# 0  cell phone    electronics     399.99           6  1-Jun
# 1       razor  personal care       4.92           2  1-Jun
# 5  cell phone    electronics     399.99           8  4-Jun

# %%
df.iloc[[0,1,5],[0,3]]
# Out:
#          item  num_thefts
# 0  cell phone           6
# 1       razor           2
# 5  cell phone           8

# %%
reference_num=[3456,3457,3485,3459,3460,3461]
df.index=reference_num
df
# Out:
#                item      item_dept  item_cost  num_thefts   date
# 3456     cell phone    electronics     399.99           6  1-Jun
# 3457          razor  personal care       4.92           2  1-Jun
# 3485     cell phone    electronics     399.99           4  2-Jun
# 3459  phone charger    electronics       6.99           1  2-Jun
# 3460      sunscreen  personal care       7.98           1  3-Jun
# 3461     cell phone    electronics     399.99           8  4-Jun

# %%
df.loc[3459]
# Out:
# item          phone charger
# item_dept       electronics
# item_cost              6.99
# num_thefts                1
# date                  2-Jun
# Name: 3459, dtype: object

# %%
df.loc[[3459]]
# Out:
#                item    item_dept  item_cost  num_thefts   date
# 3459  phone charger  electronics       6.99           1  2-Jun

# %%
df.loc[[3485,3459]]
# Out:
#                item    item_dept  item_cost  num_thefts   date
# 3485     cell phone  electronics     399.99           4  2-Jun
# 3459  phone charger  electronics       6.99           1  2-Jun

# %%
df.loc[[3485,3459],['item_cost','num_thefts']]
# Out:
#       item_cost  num_thefts
# 3485     399.99           4
# 3459       6.99           1
